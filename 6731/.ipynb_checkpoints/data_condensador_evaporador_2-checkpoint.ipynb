# %%
# %matplotlib notebook
import scipy.io as scio
from scipy import interpolate
import pylab, socket
import numpy as np
import matplotlib.pyplot as plt
import glob,os
import sys
import matplotlib as mpl
from tikzplotlib import save as tikz_save
mpl.rcParams['xtick.labelsize'] = 16;
mpl.rcParams['xtick.labelsize'] = 16;
mpl.rcParams['ytick.labelsize'] = 16;
mpl.rcParams['font.family'] = 'serif';
mpl.rcParams['axes.labelsize'] = 16
colorsk = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
A = open('data_condens_ebull.csv','r')
A.readline()
data = A.readlines()
out1 = []
for i,datai in enumerate(data):
    aux1 = datai.replace('",',' ').replace('\n','').replace(',','.').replace('"','').split(' ')
    out1.append((np.float(aux1[0]),np.float(aux1[1])))
data = np.asarray(out1)

# %%
datai
# Out:
# '"35,2","8,664e+04"\n'

# %%
fig0,ax0 = plt.subplots(figsize=(4,6))
ax0.loglog(data[:,0],data[:,1],linewidth=2,color='r')
ax0.grid(which='minor')
ax0.set_xlim([1,100])
ax0.set_ylim([1e2,1e5])
# Out:
# <img src="data:image/png;base64,..." width="400">
# (100.0, 100000.0)

# %%
ax0.grid?

# %%
data
# Out:
# array([[1.7590e+00, 8.2020e+00, 1.8435e+01, 2.8288e+01, 3.5117e+01,
#         4.2719e+01, 4.6911e+01, 5.0919e+01, 5.4529e+01, 5.8718e+01,
#         6.0143e+01, 6.2107e+01, 6.2910e+01, 6.4071e+01, 6.4832e+01,
#         6.5200e+01, 6.6792e+01, 6.7094e+01, 6.8997e+01, 6.9352e+01,
#         7.3256e+01, 7.3857e+01, 7.4458e+01, 7.4673e+01, 7.4758e+01,
#         7.7159e+01, 7.7910e+01, 7.9261e+01],
#        [8.7600e+02, 6.0590e+03, 1.4094e+04, 2.1870e+04, 2.9115e+04,
#         4.0740e+04, 5.0289e+04, 5.9004e+04, 6.6292e+04, 7.4810e+04,
#         7.9283e+04, 8.3176e+04, 8.4359e+04, 8.7069e+04, 8.9934e+04,
#         9.0292e+04, 9.2703e+04, 9.3216e+04, 9.5379e+04, 9.5475e+04,
#         9.7028e+04, 9.7291e+04, 9.7545e+04, 9.7613e+04, 9.7649e+04,
#         9.8173e+04, 9.8483e+04, 9.8694e+04]])
