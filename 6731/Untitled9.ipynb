# %%
# %matplotlib widget
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from tikzplotlib import save as savetikz

# %%
def f(z):
    return 1/z**2  #definig function as x^2

x = np.arange(-5,5,np.pi/10) #real part of input
y = np.arange(-5,5,np.pi/10) #imaginary part of input

X,Y = np.meshgrid(x,y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
