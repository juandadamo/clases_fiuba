# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-13694e348097> in <module>
#       1 h = 400 * ureg.watt/ureg.K/ureg.m**2
# ----> 2 print(h)
#
# ~/.local/lib/python3.8/site-packages/pint/quantity.py in __str__(self)
#     284     def __str__(self):
#     285         if self._REGISTRY.fmt_locale is not None:
# --> 286             return self.format_babel()
#     287
#     288         return format(self)
#
# ~/.local/lib/python3.8/site-packages/pint/quantity.py in format_babel(self, spec, **kwspec)
#     429         return "{} {}".format(
#     430             format(obj.magnitude, remove_custom_flags(spec)),
# --> 431             obj.units.format_babel(spec, **kwspec),
#     432         ).replace("\n", "")
#     433
#
# ~/.local/lib/python3.8/site-packages/pint/unit.py in format_babel(self, spec, **kwspec)
#     110             units = self._units
#     111
# ...

# %%
Ti = 373*ureg.K**-1
print(Ti)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-eaad8c8905c7> in <module>
#       1 Ti = 373*ureg.K**-1
# ----> 2 print(Ti)
#
# ~/.local/lib/python3.8/site-packages/pint/quantity.py in __str__(self)
#     284     def __str__(self):
#     285         if self._REGISTRY.fmt_locale is not None:
# --> 286             return self.format_babel()
#     287
#     288         return format(self)
#
# ~/.local/lib/python3.8/site-packages/pint/quantity.py in format_babel(self, spec, **kwspec)
#     429         return "{} {}".format(
#     430             format(obj.magnitude, remove_custom_flags(spec)),
# --> 431             obj.units.format_babel(spec, **kwspec),
#     432         ).replace("\n", "")
#     433
#
# ~/.local/lib/python3.8/site-packages/pint/unit.py in format_babel(self, spec, **kwspec)
#     110             units = self._units
#     111
# ...

# %%
h
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.8/site-packages/pint/util.py in _repr_html_(self)
#     845             return "{:~H}".format(self)
#     846         else:
# --> 847             return "{:H}".format(self)
#     848
#     849     def _repr_latex_(self):
#
# ~/.local/lib/python3.8/site-packages/pint/quantity.py in __format__(self, spec)
#     308     def __format__(self, spec):
#     309         if self._REGISTRY.fmt_locale is not None:
# --> 310             return self.format_babel(spec)
#     311
# ...
