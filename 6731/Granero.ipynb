# %%
# -*- coding: utf-8 -*-
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import ht
import CoolProp as cp
import fluids

# %% [markdown]
# Un edificio agrícola de gran longitud está recubierto de un techo de tejas que forma un diedro de ángulo $\theta=60^\circ$C. El edificio se rellena con forraje hasta el nivel de la base del techo, de superficie $S_3$.
# Se busca calcular la temperatura estacionaria $T_3$ de esta superficie, considerada como adiabática, en los siguientes casos:
# 1. La radiación solar cae verticalmente sobre el techo (sol cenital).
# 2. la radiación solar cae perpendicular a uno de los dos costados del techo.
#
# Se adoptan las siguientes hipótesis:
# - La irradiación solar normal vale $E_S=750$W /m$^2$.
# - Todas las superficies son negras.
# - Al interior del techo, los intercambios son puramente radiativos.
# - Los intercambios por convección y radiación con el ambiente son descriptos con un solo coeficiente $h=30$ W/m$^2$K. La temperatura exterior es $T_o = 295 K$. La conducción térmica de las tejas, de espesor $e=3$cm, es k=1 W/m$^2$K.
# - Considere simetrías y la descripción gráfica de la figura.

# %% [markdown]
# ![granero.png](attachment:granero.png)

# %%
Es = 750
T0 = 295
h = 30

#Es*2*(A/2*sin(30)) = h*(T1'-T0)*A

T1 = Es/h*np.sin(30*np.pi/180)+T0
T1 - 273
# Out:
# 34.5
